# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanda1020/OpenCV/blob/master/01Fundamental/Day02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import cv2
from google.colab.patches import cv2_imshow
img_path ='/content/gdrive/My Drive/openCV/01Fundamental/lena.png'
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
cv2_imshow(img)
cv2_imshow(img_hsv)
cv2_imshow(img_lab)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA7A6739F98>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA7A6739908>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA7A6739EF0>
